# %% [markdown]
# <a href="https://colab.research.google.com/github/SarangRao20/AI/blob/main/Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import mediapipe as mp
import pydirectinput
import time
import webbrowser

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
webbrowser.open('https://poki.com/en/g/temple-run-2')
time.sleep(2)  # Wait a few seconds for the page to load

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                if x < w // 3:
                    pydirectinput.press("left")
                    action = "Left"
                elif x > 2 * w // 3:
                    pydirectinput.press("right")
                    action = "Right"
                elif y < h // 3:
                    pydirectinput.press("up")
                    action = "Jump"
                elif y > 2 * h // 3:
                    pydirectinput.press("down")
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    cv2.imshow("Finger Control - Temple Run", img)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-2e60d47773cd> in <cell line: 0>()
#       1 import cv2
#       2 import mediapipe as mp
# ----> 3 import pydirectinput
#       4 import time
#       5 import webbrowser
#
# /usr/local/lib/python3.11/dist-packages/pydirectinput/__init__.py in <module>
#       4 import time
#       5
# ----> 6 SendInput = ctypes.windll.user32.SendInput
#       7 MapVirtualKey = ctypes.windll.user32.MapVirtualKeyW
#       8
#
# AttributeError: module 'ctypes' has no attribute 'windll'

# %%
# !pip install pynput

import cv2
import mediapipe as mp
from pynput.keyboard import Key, Controller
keyboard = Controller()

import time
import webbrowser

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
webbrowser.open('https://poki.com/en/g/temple-run-2')
time.sleep(2)  # Wait a few seconds for the page to load

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

keyboard = Controller()  # Create a keyboard controller object

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                if x < w // 3:
                    keyboard.press(Key.left)  # Press the left arrow key
                    keyboard.release(Key.left)  # Release the left arrow key
                    action = "Left"
                elif x > 2 * w // 3:
                    keyboard.press(Key.right)  # Press the right arrow key
                    keyboard.release(Key.right)  # Release the right arrow key
                    action = "Right"
                elif y < h // 3:
                    keyboard.press(Key.up)  # Press the up arrow key
                    keyboard.release(Key.up)  # Release the up arrow key
                    action = "Jump"
                elif y > 2 * h // 3:
                    keyboard.press(Key.down)  # Press the down arrow key
                    keyboard.release(Key.down)  # Release the down arrow key
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    cv2.imshow("Finger Control - Temple Run", img)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-52d6dc954fdb> in <cell line: 0>()
#       3 import cv2
#       4 import mediapipe as mp
# ----> 5 from pynput.keyboard import Key, Controller
#       6 keyboard = Controller()
#       7
#
# /usr/local/lib/python3.11/dist-packages/pynput/__init__.py in <module>
#      38
#      39
# ---> 40 from . import keyboard
#      41 from . import mouse
#
# /usr/local/lib/python3.11/dist-packages/pynput/keyboard/__init__.py in <module>
#      29
#      30
# ---> 31 backend = backend(__name__)
#      32 KeyCode = backend.KeyCode
#      33 Key = backend.Key
#
# ...

# %%
# !pip install pyautogui

import cv2
import mediapipe as mp
import pyautogui  # Import pyautogui instead of pynput
import time
import webbrowser

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
webbrowser.open('https://poki.com/en/g/temple-run-2')
time.sleep(2)  # Wait a few seconds for the page to load

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                if x < w // 3:
                    pyautogui.press("left")  # Use pyautogui.press instead of keyboard.press
                    action = "Left"
                elif x > 2 * w // 3:
                    pyautogui.press("right")  # Use pyautogui.press instead of keyboard.press
                    action = "Right"
                elif y < h // 3:
                    pyautogui.press("up")  # Use pyautogui.press instead of keyboard.press
                    action = "Jump"
                elif y > 2 * h // 3:
                    pyautogui.press("down")  # Use pyautogui.press instead of keyboard.press
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    cv2.imshow("Finger Control - Temple Run", img)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# /usr/local/lib/python3.11/dist-packages/jaxlib/plugin_support.py:71: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.5.1 is installed, but it is not compatible with the installed jaxlib version 0.5.3, so it will not be used.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1-6495498600e5> in <cell line: 0>()
#       3 import cv2
#       4 import mediapipe as mp
# ----> 5 import pyautogui  # Import pyautogui instead of pynput
#       6 import time
#       7 import webbrowser
#
# /usr/local/lib/python3.11/dist-packages/pyautogui/__init__.py in <module>
#     244
# ...

# %%
# !pip install pyvirtualdisplay
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...

# %%
# !pip install pynput
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.7/91.7 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.2/182.2 kB 9.3 MB/s eta 0:00:00
# ...
#   Created wheel for evdev: filename=evdev-1.9.1-cp311-cp311-linux_x86_64.whl size=112923 sha256=128881f019796433e2da8274ab7e8ce22f9c811fc217f03d408b54969d679636
#   Stored in directory: /root/.cache/pip/wheels/02/d5/b9/4d822cda539839703ddcd1419aea072768b372844a6b94d518
# Successfully built evdev
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...

# %%
# !apt-get update
# !apt-get install -y xvfb

import os
os.environ['DISPLAY'] = ':99' # Set the DISPLAY environment variable

from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 600))
display.start()
# ... rest of your code

import cv2
import mediapipe as mp
import pyautogui  # Import pyautogui instead of pynput
import time
import webbrowser

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
webbrowser.open('https://poki.com/en/g/temple-run-2')
time.sleep(2)  # Wait a few seconds for the page to load

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                if x < w // 3:
                    pyautogui.press("left")  # Use pyautogui.press instead of keyboard.press
                    action = "Left"
                elif x > 2 * w // 3:
                    pyautogui.press("right")  # Use pyautogui.press instead of keyboard.press
                    action = "Right"
                elif y < h // 3:
                    pyautogui.press("up")  # Use pyautogui.press instead of keyboard.press
                    action = "Jump"
                elif y > 2 * h // 3:
                    pyautogui.press("down")  # Use pyautogui.press instead of keyboard.press
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    cv2.imshow("Finger Control - Temple Run", img)
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,383 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,688 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,824 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !apt-get update
# !apt-get install -y xvfb

import os
os.environ['DISPLAY'] = ':99' # Set the DISPLAY environment variable

from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 600))
display.start()
# ... rest of your code

import cv2
import mediapipe as mp
import pyautogui  # Import pyautogui instead of pynput
import time
import webbrowser

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
# webbrowser.open('https://poki.com/en/g/temple-run-2') # Commented out for testing purposes - feel free to uncomment
# time.sleep(2)  # Wait a few seconds for the page to load # Commented out for testing purposes - feel free to uncomment

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                if x < w // 3:
                    pyautogui.press("left")  # Use pyautogui.press instead of keyboard.press
                    action = "Left"
                elif x > 2 * w // 3:
                    pyautogui.press("right")  # Use pyautogui.press instead of keyboard.press
                    action = "Right"
                elif y < h // 3:
                    pyautogui.press("up")  # Use pyautogui.press instead of keyboard.press
                    action = "Jump"
                elif y > 2 * h // 3:
                    pyautogui.press("down")  # Use pyautogui.press instead of keyboard.press
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    # cv2.imshow("Finger Control - Temple Run", img) # Commented out for testing purposes - feel free to uncomment
    # if cv2.waitKey(1) & 0xFF == ord("q"): # Commented out for testing purposes - feel free to uncomment
    #     break # Commented out for testing purposes - feel free to uncomment

    # Added break condition
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !sudo apt-get install xvfb
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.14).
# 0 upgraded, 0 newly installed, 0 to remove and 47 not upgraded.

# %%
# !xvfb-run -s "-screen 0 640x480x24" python Untitled9.ipynb
# Out:
# python3: can't open file '/content/Untitled9.ipynb': [Errno 2] No such file or directory

# %%
# !xvfb-run -s "-screen 0 640x480x24" python your_script.py
# Out:
# python3: can't open file '/content/your_script.py': [Errno 2] No such file or directory

# %%
# !pip install pydirectinput
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...

# %%
# !pip install --upgrade mediapipe==4.10.1
# !pip install protobuf==3.20.3
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ERROR: Could not find a version that satisfies the requirement mediapipe==4.10.1 (from versions: 0.10.5, 0.10.7, 0.10.8, 0.10.9, 0.10.10, 0.10.11, 0.10.13, 0.10.14, 0.10.15, 0.10.18, 0.10.20, 0.10.21)
# ERROR: No matching distribution found for mediapipe==4.10.1
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 3.7 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
#   Attempting uninstall: protobuf
#     WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
#     Found existing installation: protobuf 4.25.6
# ...

# %%
# !pip install --upgrade numpy
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
#   Using cached numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires numpy<2, but you have numpy 2.2.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.4 which is incompatible.
# ...

# %%
# !pip install --upgrade --force-reinstall numpy
# !pip install --upgrade --force-reinstall mediapipe
# !pip install --upgrade --force-reinstall pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 40.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires numpy<2, but you have numpy 2.2.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.4 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.4 which is incompatible.
# ...
#   Using cached mediapipe-0.10.21-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.7 kB)
# ...
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...

# %%
# !pip install mediapipe
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.1 which is incompatible.
# ...

# %%
# !pip install --upgrade protobuf
# !pip install mediapipe
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.2/316.2 kB 5.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mediapipe 0.10.21 requires protobuf<5,>=4.25.3, but you have protobuf 6.30.2 which is incompatible.
# wandb 0.19.9 requires protobuf!=4.21.0,!=5.28.0,<6,>=3.19.0; python_version > "3.9" and sys_platform == "linux", but you have protobuf 6.30.2 which is incompatible.
# google-ai-generativelanguage 0.6.15 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2, but you have protobuf 6.30.2 which is incompatible.
# ...

# %%
# !apt-get update
# !apt-get install -y xvfb

import os
os.environ['DISPLAY'] = ':99' # Set the DISPLAY environment variable

from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 600))
display.start()
# ... rest of your code

import cv2
import mediapipe as mp
import pyautogui  # Import pyautogui instead of pynput
import time
import webbrowser

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
# webbrowser.open('https://poki.com/en/g/temple-run-2') # Commented out for testing purposes - feel free to uncomment
# time.sleep(2)  # Wait a few seconds for the page to load # Commented out for testing purposes - feel free to uncomment

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                if x < w // 3:
                    pyautogui.press("left")  # Use pyautogui.press instead of keyboard.press
                    action = "Left"
                elif x > 2 * w // 3:
                    pyautogui.press("right")  # Use pyautogui.press instead of keyboard.press
                    action = "Right"
                elif y < h // 3:
                    pyautogui.press("up")  # Use pyautogui.press instead of keyboard.press
                    action = "Jump"
                elif y > 2 * h // 3:
                    pyautogui.press("down")  # Use pyautogui.press instead of keyboard.press
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    # cv2.imshow("Finger Control - Temple Run", img) # Commented out for testing purposes - feel free to uncomment
    # if cv2.waitKey(1) & 0xFF == ord("q"): # Commented out for testing purposes - feel free to uncomment
    #     break # Commented out for testing purposes - feel free to uncomment

    # Added break condition
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !apt-get update
# !apt-get install -y xvfb

import os
os.environ['DISPLAY'] = ':99' # Set the DISPLAY environment variable

from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 600))
display.start()
# ... rest of your code

import cv2
import mediapipe as mp
import pyautogui  # Import pyautogui instead of pynput
import time
import webbrowser

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
# webbrowser.open('https://poki.com/en/g/temple-run-2') # Commented out for testing purposes - feel free to uncomment
# time.sleep(2)  # Wait a few seconds for the page to load # Commented out for testing purposes - feel free to uncomment

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                if x < w // 3:
                    pyautogui.press("left")  # Use pyautogui.press instead of keyboard.press
                    action = "Left"
                elif x > 2 * w // 3:
                    pyautogui.press("right")  # Use pyautogui.press instead of keyboard.press
                    action = "Right"
                elif y < h // 3:
                    pyautogui.press("up")  # Use pyautogui.press instead of keyboard.press
                    action = "Jump"
                elif y > 2 * h // 3:
                    pyautogui.press("down")  # Use pyautogui.press instead of keyboard.press
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    # cv2.imshow("Finger Control - Temple Run", img) # Commented out for testing purposes - feel free to uncomment
    # if cv2.waitKey(1) & 0xFF == ord("q"): # Commented out for testing purposes - feel free to uncomment
    #     break # Commented out for testing purposes - feel free to uncomment

    # Break the loop after a certain time to avoid infinite loop in the testing environment

    # Added break condition for testing in Google Colab
    break  # This line is for testing purposes and will need to be removed when running the full code


cap.release()
cv2.destroyAllWindows()
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !apt-get update
# !apt-get install -y xvfb

import os
os.environ['DISPLAY'] = ':99' # Set the DISPLAY environment variable

from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 600))
display.start()

# ... (Rest of your code)


import cv2
import mediapipe as mp
import pyautogui  # Import pyautogui instead of pynput
import time
import webbrowser

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
# webbrowser.open('https://poki.com/en/g/temple-run-2') # Commented out for testing purposes - feel free to uncomment
# time.sleep(2)  # Wait a few seconds for the page to load # Commented out for testing purposes - feel free to uncomment

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                if x < w // 3:
                    pyautogui.press("left")  # Use pyautogui.press instead of keyboard.press
                    action = "Left"
                elif x > 2 * w // 3:
                    pyautogui.press("right")  # Use pyautogui.press instead of keyboard.press
                    action = "Right"
                elif y < h // 3:
                    pyautogui.press("up")  # Use pyautogui.press instead of keyboard.press
                    action = "Jump"
                elif y > 2 * h // 3:
                    pyautogui.press("down")  # Use pyautogui.press instead of keyboard.press
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    # cv2.imshow("Finger Control - Temple Run", img) # Commented out for testing purposes - feel free to uncomment
    # if cv2.waitKey(1) & 0xFF == ord("q"): # Commented out for testing purposes - feel free to uncomment
    #     break # Commented out for testing purposes - feel free to uncomment

    # Break the loop after a certain time to avoid infinite loop in the testing environment

    # Added break condition for testing in Google Colab
    break  # This line is for testing purposes and will need to be removed when running the full code


cap.release()
cv2.destroyAllWindows()
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !apt-get update
# !apt-get install -y xvfb

import os
os.environ['DISPLAY'] = ':99' # Set the DISPLAY environment variable

from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 600))
display.start()

# ... (Rest of your code)


import cv2
import mediapipe as mp
import pyautogui  # Import pyautogui instead of pynput
import time
import webbrowser

# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
# webbrowser.open('https://poki.com/en/g/temple-run-2') # Commented out for testing purposes - feel free to uncomment
# time.sleep(2)  # Wait a few seconds for the page to load # Commented out for testing purposes - feel free to uncomment

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                if x < w // 3:
                    pyautogui.press("left")  # Use pyautogui.press instead of keyboard.press
                    action = "Left"
                elif x > 2 * w // 3:
                    pyautogui.press("right")  # Use pyautogui.press instead of keyboard.press
                    action = "Right"
                elif y < h // 3:
                    pyautogui.press("up")  # Use pyautogui.press instead of keyboard.press
                    action = "Jump"
                elif y > 2 * h // 3:
                    pyautogui.press("down")  # Use pyautogui.press instead of keyboard.press
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    # cv2.imshow("Finger Control - Temple Run", img) # Commented out for testing purposes - feel free to uncomment
    # if cv2.waitKey(1) & 0xFF == ord("q"): # Commented out for testing purposes - feel free to uncomment
    #     break # Commented out for testing purposes - feel free to uncomment

    # Break the loop after a certain time to avoid infinite loop in the testing environment

    # Added break condition for testing in Google Colab
    break  # This line is for testing purposes and will need to be removed when running the full code


cap.release()
cv2.destroyAllWindows()
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !apt-get update
# !apt-get install -y xvfb

import os
os.environ['DISPLAY'] = ':99' # Set the DISPLAY environment variable

from pyvirtualdisplay import Display
display = Display(visible=0, size=(800, 600))
display.start()

# ... (Rest of your code)


import cv2
import mediapipe as mp
import pyautogui  # Import pyautogui instead of pynput
import time
import webbrowser
import numpy as np # Import numpy for image processing


# Initialize MediaPipe Hands
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(max_num_hands=1, min_detection_confidence=0.7)
mp_draw = mp.solutions.drawing_utils

# Open the browser and add a delay
# webbrowser.open('https://poki.com/en/g/temple-run-2') # Commented out for testing purposes - feel free to uncomment
# time.sleep(2)  # Wait a few seconds for the page to load # Commented out for testing purposes - feel free to uncomment

# Initialize the webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

last_action_time = time.time()
cooldown = 0.1  # Increased cooldown (0.1 seconds)

while True:
    success, img = cap.read()
    if not success:
        print("Failed to read frame from webcam.")
        break

    img = cv2.flip(img, 1)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    results = hands.process(img_rgb)

    h, w, c = img.shape

    if results.multi_hand_landmarks:
        for handLms in results.multi_hand_landmarks:
            mp_draw.draw_landmarks(img, handLms, mp_hands.HAND_CONNECTIONS)

            index_tip = handLms.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP]
            x, y = int(index_tip.x * w), int(index_tip.y * h)

            # Draw index tip
            cv2.circle(img, (x, y), 10, (0, 255, 0), cv2.FILLED)

            current_time = time.time()

            if current_time - last_action_time > cooldown:
                # Capture screenshot of virtual display
                screenshot = pyautogui.screenshot()
                screenshot_np = np.array(screenshot)
                screenshot_cv = cv2.cvtColor(screenshot_np, cv2.COLOR_RGB2BGR)

                # Assuming the game window is in the center of the screen
                # Adjust these coordinates if necessary
                game_window_x = screenshot_cv.shape[1] // 4  # Starting X-coordinate of the game window
                game_window_y = screenshot_cv.shape[0] // 4  # Starting Y-coordinate of the game window
                game_window_width = screenshot_cv.shape[1] // 2  # Width of the game window
                game_window_height = screenshot_cv.shape[0] // 2  # Height of the game window

                if x < w // 3:
                    pyautogui.click(game_window_x + game_window_width // 4, game_window_y + game_window_height // 2)  # Click on the left side of the game window
                    action = "Left"
                elif x > 2 * w // 3:
                    pyautogui.click(game_window_x + 3 * game_window_width // 4, game_window_y + game_window_height // 2)  # Click on the right side of the game window
                    action = "Right"
                elif y < h // 3:
                    pyautogui.click(game_window_x + game_window_width // 2, game_window_y + game_window_height // 4)  # Click on the top side of the game window
                    action = "Jump"
                elif y > 2 * h // 3:
                    pyautogui.click(game_window_x + game_window_width // 2, game_window_y + 3 * game_window_height // 4)  # Click on the bottom side of the game window
                    action = "Slide"
                else:
                    action = "Run"

                last_action_time = current_time

                cv2.putText(img, f'Action: {action}', (10, 30),
                            cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 255), 2)

    # Draw region lines
    cv2.line(img, (w // 3, 0), (w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (2 * w // 3, 0), (2 * w // 3, h), (255, 255, 255), 2)
    cv2.line(img, (0, h // 3), (w, h // 3), (255, 255, 255), 2)
    cv2.line(img, (0, 2 * h // 3), (w, 2 * h // 3), (255, 255, 255), 2)

    # Break the loop after a certain time to avoid infinite loop in the testing environment

    # Added break condition for testing in Google Colab
    break  # This line is for testing purposes and will need to be removed when running the full code


cap.release()
cv2.destroyAllWindows()
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %%
# !pip install pyautogui
# Out:
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~umpy (/usr/local/lib/python3.11/dist-packages)
